# %%
import configparser
from datetime import datetime
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col
from pyspark.sql.functions import year, month, dayofmonth, hour, weekofyear, date_format
from pyspark.sql import functions as F


config = configparser.ConfigParser()
config.read('dl.cfg')

os.environ['AWS_ACCESS_KEY_ID']=config.get('AWS','AWS_ACCESS_KEY_ID')
os.environ['AWS_SECRET_ACCESS_KEY']=config.get('AWS','AWS_SECRET_ACCESS_KEY')

#os.environ['AWS_ACCESS_KEY_ID']=config['AWS_ACCESS_KEY_ID']
#os.environ['AWS_SECRET_ACCESS_KEY']=config['AWS_SECRET_ACCESS_KEY']

# %%
# the entry point of a spark application
spark = SparkSession.builder.config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0").getOrCreate()

# %%
# read song_data s3 input
df = spark.read.json("s3a://udacity-dend/song_data/A/B/C/TRABCEI128F424C983.json")
df.printSchema()
df.show(5)
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_latitude: string (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_longitude: string (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- num_songs: long (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: long (nullable = true)
#
# +------------------+---------------+---------------+----------------+-----------+---------+---------+------------------+-------------------+----+
# |         artist_id|artist_latitude|artist_location|artist_longitude|artist_name| duration|num_songs|           song_id|              title|year|
# +------------------+---------------+---------------+----------------+-----------+---------+---------+------------------+-------------------+----+
# |ARJIE2Y1187B994AB7|           null|               |            null|Line Renaud|152.92036|        1|SOUPIRU12A6D4FA1E1|Der Kleine Dompfaff|   0|
# +------------------+---------------+---------------+----------------+-----------+---------+---------+------------------+-------------------+----+

# %%
# read log_data from s3 input
dff = spark.read.json("s3a://udacity-dend/log_data/2018/11/2018-11-12-events.json")
dff.printSchema()
dff.show(5)
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: double (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)
#
# +--------------------+---------+----------+------+-------------+--------+---------+-----+--------------------+------+--------+-----------------+---------+--------------------+------+-------------+--------------------+------+
# |              artist|     auth| firstName|gender|itemInSession|lastName|   length|level|            location|method|    page|     registration|sessionId|                song|status|           ts|           userAgent|userId|
# +--------------------+---------+----------+------+-------------+--------+---------+-----+--------------------+------+--------+-----------------+---------+--------------------+------+-------------+--------------------+------+
# |                null|Logged In|   Celeste|     F|            0|Williams|     null| free|   Klamath Falls, OR|   GET|    Home|1.541077528796E12|      438|                null|   200|1541990217796|"Mozilla/5.0 (Win...|    53|
# |            Pavement|Logged In|    Sylvie|     F|            0|    Cruz| 99.16036| free|Washington-Arling...|   PUT|NextSong|1.540266185796E12|      345|Mercy:The Laundromat|   200|1541990258796|"Mozilla/5.0 (Mac...|    10|
# |Barry Tuckwell/Ac...|Logged In|   Celeste|     F|            1|Williams|277.15873| free|   Klamath Falls, OR|   PUT|NextSong|1.541077528796E12|      438|Horn Concerto No....|   200|1541990264796|"Mozilla/5.0 (Win...|    53|
# |          Gary Allan|Logged In|   Celeste|     F|            2|Williams|211.22567| free|   Klamath Falls, OR|   PUT|NextSong|1.541077528796E12|      438|Nothing On But Th...|   200|1541990541796|"Mozilla/5.0 (Win...|    53|
# |                null|Logged In|Jacqueline|     F|            0|   Lynch|     null| paid|Atlanta-Sandy Spr...|   GET|    Home|1.540223723796E12|      389|                null|   200|1541990714796|"Mozilla/5.0 (Mac...|    29|
# +--------------------+---------+----------+------+-------------+--------+---------+-----+--------------------+------+--------+-----------------+---------+--------------------+------+-------------+--------------------+------+
# only showing top 5 rows

# %%
# Create output s3 pucket which 'abdullahoutput' in our case in region 'us-west-2'
import boto3

s3a = boto3.client('s3')
region='us-west-2'
s3a.create_bucket(Bucket='abdullahoutput', CreateBucketConfiguration={ 'LocationConstraint' : region})
# Out:
# {'ResponseMetadata': {'RequestId': '1ZDFVKE9KZ7M6KS8',
#   'HostId': 'XuyFiof3GTEDNjpgtiN7Iw7qic12kUKmnLfGS2IsmJJ84mvAX4XOgCfTOyh/4UGWIrM7Xax8rRY=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'XuyFiof3GTEDNjpgtiN7Iw7qic12kUKmnLfGS2IsmJJ84mvAX4XOgCfTOyh/4UGWIrM7Xax8rRY=',
#    'x-amz-request-id': '1ZDFVKE9KZ7M6KS8',
#    'date': 'Sat, 05 Nov 2022 01:11:46 GMT',
#    'location': 'http://abdullahoutput.s3.amazonaws.com/',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'Location': 'http://abdullahoutput.s3.amazonaws.com/'}

# %%
# Run the command python etl.py in terminal to execute the ETL steps.
# !python etl.py

# %%
# explore the objects for songs_table
import boto3

s3 = boto3.resource('s3',
                       region_name="us-west-2",
                       aws_access_key_id=os.environ['AWS_ACCESS_KEY_ID'],
                       aws_secret_access_key=os.environ['AWS_SECRET_ACCESS_KEY'])

my_bucket = s3.Bucket('abdullahoutput')
for my_bucket_object in my_bucket.objects.filter(Prefix='songs_table'):
    print(my_bucket_object)
# Out:
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/_SUCCESS')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=0/artist_id=AR10USD1187B99F3F1/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=0/artist_id=AR1C2IX1187B99BF74/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=0/artist_id=AR1KTV21187B9ACD72/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=0/artist_id=AR9Q9YC1187FB5609B/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=0/artist_id=ARA23XO1187B9AF18F/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=0/artist_id=ARC1IHZ1187FB4E920/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=0/artist_id=ARKYKXP11F50C47A6A/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=0/artist_id=ARZ5H0P1187B98A1DD/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=0/artist_id=ARZKCQM1257509D107/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=1969/artist_id=ARMJAGH1187FB546F3/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=1972/artist_id=ARTC1LV1187B9A4858/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=1978/artist_id=AR5LMPY1187FB573FE/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=1985/artist_id=ARXQBR11187B98A2CC/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=1989/artist_id=ARCLYBR1187FB53913/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=2000/artist_id=AR0MWD61187B9B2B12/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=2001/artist_id=ARSVTNL1187B992A91/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=2004/artist_id=AREWD471187FB49873/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=2004/artist_id=ARSZ7L31187FB4E610/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=2004/artist_id=ARY589G1187B9A9F4E/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=2005/artist_id=AR73AIO1187B9AD57B/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=2006/artist_id=ARBZIN01187FB362CC/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=2007/artist_id=ARXR32B1187FB57099/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=2008/artist_id=ARGE7G11187FB37E05/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songs_table/year=2009/artist_id=ARJNIUY12298900C91/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet')

# %%
# read songs_table
df_song = spark.read.parquet("s3a://abdullahoutput/songs_table/year=2009/artist_id=ARJNIUY12298900C91/part-00000-56d1cdba-91d7-403e-8279-7dce1a734b0f.c000.snappy.parquet")
df_song.printSchema()
df_song.show(5)
# Out:
# root
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- duration: double (nullable = true)
#
# +------------------+------+--------+
# |           song_id| title|duration|
# +------------------+------+--------+
# |SOBLFFE12AF72AA5BA|Scream|213.9424|
# +------------------+------+--------+

# %%
# explore the objects for artists_table

my_bucket = s3.Bucket('abdullahoutput')
for my_bucket_object in my_bucket.objects.filter(Prefix='artists_table'):
    print(my_bucket_object)
# Out:
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/_SUCCESS')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00000-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00007-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00010-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00023-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00030-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00053-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00054-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00055-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00058-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00080-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00089-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00090-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00110-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00112-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00117-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00144-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00153-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00165-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00167-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00175-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00177-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='artists_table/part-00193-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet')

# %%
# read artists_table
df_artists = spark.read.parquet("s3a://abdullahoutput/artists_table/part-00175-955074f5-6b23-4f4e-8983-776aa29cfdb2-c000.snappy.parquet")
df_artists.printSchema()
df_artists.show(5)
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_latitude: double (nullable = true)
#  |-- artist_longitude: double (nullable = true)
#
# +------------------+--------------------+---------------+---------------+----------------+
# |         artist_id|         artist_name|artist_location|artist_latitude|artist_longitude|
# +------------------+--------------------+---------------+---------------+----------------+
# |AR0MWD61187B9B2B12|International Noi...|               |           null|            null|
# +------------------+--------------------+---------------+---------------+----------------+

# %%
# explore the objects for users_table

my_bucket = s3.Bucket('abdullahoutput')
for my_bucket_object in my_bucket.objects.filter(Prefix='users_table'):
    print(my_bucket_object)
# Out:
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/_SUCCESS')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00000-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00002-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00006-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00008-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00009-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00010-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00012-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00014-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00018-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00024-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00028-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00029-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00036-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00039-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00040-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00045-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00046-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00048-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00049-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00051-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00052-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00054-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00055-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00057-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00060-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00061-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00062-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00064-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00068-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00070-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00073-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00074-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00077-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00078-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00079-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00084-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00085-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00093-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00094-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00096-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00097-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00100-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00102-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00104-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00109-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00113-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00114-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00119-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00120-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00122-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00125-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00126-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00128-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00129-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00135-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00137-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00140-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00146-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00147-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00149-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00155-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00158-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00160-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00161-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00163-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00169-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00170-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00172-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00174-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00176-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00177-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00178-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00179-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00180-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00182-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00183-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00187-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00188-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00193-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00194-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='users_table/part-00196-dbef0345-04d1-4cff-80c2-31ef51e9ca9a-c000.snappy.parquet')

# %%
# read users_table

df_users = spark.read.parquet("s3a://abdullahoutput/users_table/part-00194-b428205e-2450-4e0f-bea9-a032a6e788d7-c000.snappy.parquet")
df_users.printSchema()
df_users.show(5)
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- level: string (nullable = true)
#
# +-------+----------+---------+------+-----+
# |user_id|first_name|last_name|gender|level|
# +-------+----------+---------+------+-----+
# |    101|    Jayden|      Fox|     M| free|
# |     20|     Aiden|  Ramirez|     M| paid|
# |      3|     Isaac|   Valdez|     M| free|
# +-------+----------+---------+------+-----+

# %%
# explore the objects for time_table

my_bucket = s3.Bucket('abdullahoutput')
for my_bucket_object in my_bucket.objects.filter(Prefix='time_table'):
    print(my_bucket_object)
# Out:
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/_SUCCESS')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00000-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00001-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00002-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00003-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00004-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00005-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00006-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00007-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00008-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00009-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00010-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00011-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00012-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00013-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00014-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00015-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00016-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00017-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00018-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00019-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00020-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00021-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00022-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00023-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00024-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00025-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00026-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00027-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00028-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00029-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00030-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00031-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00032-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00033-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00034-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00035-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00036-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00037-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00038-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00039-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00040-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00041-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00042-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00043-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00044-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00045-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00046-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00047-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00048-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00049-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00050-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00051-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00052-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00053-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00054-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00055-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00056-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00057-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00058-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00059-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00060-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00061-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00062-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00063-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00064-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00065-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00066-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00067-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00068-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00069-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00070-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00071-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00072-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00073-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00074-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00075-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00076-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00077-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00078-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00079-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00080-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00081-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00082-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00083-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00084-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00085-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00086-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00087-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00088-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00089-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00090-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00091-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00092-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00093-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00094-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00095-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00096-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00097-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00098-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00099-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00100-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00101-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00102-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00103-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00104-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00105-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00106-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00107-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00108-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00109-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00110-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00111-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00112-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00113-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00114-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00115-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00116-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00117-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00118-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00119-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00120-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00121-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00122-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00123-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00124-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00125-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00126-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00127-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00128-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00129-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00130-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00131-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00132-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00133-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00134-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00135-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00136-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00137-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00138-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00139-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00140-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00141-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00142-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00143-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00144-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00145-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00146-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00147-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00148-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00149-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00150-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00151-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00152-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00153-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00154-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00155-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00156-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00157-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00158-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00159-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00160-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00161-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00162-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00163-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00164-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00165-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00166-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00167-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00168-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00169-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00170-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00171-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00172-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00173-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00174-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00175-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00176-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00177-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00178-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00179-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00180-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00181-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00182-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00183-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00184-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00185-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00186-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00187-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00188-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00189-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00190-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00191-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00192-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00193-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00194-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00195-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00196-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00197-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00198-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')
# s3.ObjectSummary(bucket_name='abdullahoutput', key='time_table/year=2018/month=11/part-00199-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet')

# %%
# read time_table

df_time = spark.read.parquet("s3a://abdullahoutput/time_table/year=2018/month=11/part-00000-0dc9f58e-89c4-4b45-95c8-c5293edbd3db.c000.snappy.parquet")
df_time.printSchema()
df_time.show(5)
# Out:
# root
#  |-- datetime: string (nullable = true)
#  |-- start_time: string (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- week: integer (nullable = true)
#  |-- weekday: integer (nullable = true)
#
# +--------------------+--------------------+----+---+----+-------+
# |            datetime|          start_time|hour|day|week|weekday|
# +--------------------+--------------------+----+---+----+-------+
# |2018-11-15 15:37:...|2018-11-15 15:37:...|  15| 15|  46|      5|
# |2018-11-15 17:42:...|2018-11-15 17:42:...|  17| 15|  46|      5|
# |2018-11-21 04:23:...|2018-11-21 04:23:...|   4| 21|  47|      4|
# |2018-11-21 08:52:...|2018-11-21 08:52:...|   8| 21|  47|      4|
# |2018-11-21 11:42:...|2018-11-21 11:42:...|  11| 21|  47|      4|
# +--------------------+--------------------+----+---+----+-------+
# only showing top 5 rows

# %%
# explore the objects for songplays_table

my_bucket = s3.Bucket('abdullahoutput')
for my_bucket_object in my_bucket.objects.filter(Prefix='songplays_table'):
    print(my_bucket_object)
# Out:
# s3.ObjectSummary(bucket_name='abdullahoutput', key='songplays_table/_SUCCESS')
